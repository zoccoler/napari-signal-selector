# %%
from matplotlib.colors import to_hex
from matplotlib.cm import get_cmap
import numpy as np
from matplotlib import colormaps
import colorcet as cc

# %% [markdown]
# ## Display colormap with matplotlib

# %%
from matplotlib.cm import get_cmap

get_cmap("cet_glasbey_light")
get_cmap("cet_glasbey_category10")
# Out:
# C:\Users\mazo260d\AppData\Local\Temp\ipykernel_7100\1422261347.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   get_cmap("cet_glasbey_light")
# C:\Users\mazo260d\AppData\Local\Temp\ipykernel_7100\1422261347.py:4: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   get_cmap("cet_glasbey_category10")

# %%
len(cc.glasbey_category10)
# Out:
# 256

# %%
cc.glasbey_category10[:12]
# Out:
# [[0.121569, 0.466667, 0.705882],
#  [1.0, 0.498039, 0.054902],
#  [0.172549, 0.627451, 0.172549],
#  [0.839216, 0.152941, 0.156863],
#  [0.580392, 0.403922, 0.741176],
#  [0.54902, 0.337255, 0.294118],
#  [0.890196, 0.466667, 0.760784],
#  [0.498039, 0.498039, 0.498039],
#  [0.737255, 0.741176, 0.133333],
#  [0.090196, 0.745098, 0.811765],
#  [0.227451, 0.003922, 0.513725],
#  [0.0, 0.262745, 0.003922]]

# %%
cmap = cc.glasbey_category10
cmap.insert(0, [0, 0, 0, 0])
cmap[:12]
# Out:
# [[0, 0, 0, 0],
#  [0.121569, 0.466667, 0.705882],
#  [1.0, 0.498039, 0.054902],
#  [0.172549, 0.627451, 0.172549],
#  [0.839216, 0.152941, 0.156863],
#  [0.580392, 0.403922, 0.741176],
#  [0.54902, 0.337255, 0.294118],
#  [0.890196, 0.466667, 0.760784],
#  [0.498039, 0.498039, 0.498039],
#  [0.737255, 0.741176, 0.133333],
#  [0.090196, 0.745098, 0.811765],
#  [0.227451, 0.003922, 0.513725]]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([1,2,3], [1,2,3], color=cmap[1])
ax.plot([1,2,3], [2,3,4], color=cmap[2])
ax.plot([1,2,3], [3,4,5], color=cmap[3])
ax.plot([1,2,3], [4,5,6], color=cmap[4])
ax.plot([1,2,3], [5,6,7], color=cmap[5])
ax.plot([1,2,3], [6,7,8], color=cmap[11])
